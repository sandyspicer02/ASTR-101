# %% [markdown]
# ### Name: Sandy Spicer

# %% [markdown]
# # Surveying the Known Extrasolar Planets

# %% [markdown]
# Using data from Appendix 5, plot Luminosity vs. Temperature for the nearest (12ly) and brightest stars.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
luminosity = [22.9,14900,1.51,0.44,113,49.2,137,54000,7.73,1030,7180,13600,11.1,3100,163,16300,1920,32.2,17.4,1980,58600,146,3400,49,138]
temperature = [9330,7500,5800,5110,5035,9600,5010,10000,6700,17600,16000,3600,7920,26100,3780,3630,23000,4720,8750,26100,8900,13500,14000,8820,3200]
plt.figure(figsize=(5,5))
plt.plot(temperature,luminosity,'bo')
plt.xlabel('Temperature')
plt.ylabel('Luminosity')
plt.title('Luminosity vs. Temperature')
plt.yscale('log')
